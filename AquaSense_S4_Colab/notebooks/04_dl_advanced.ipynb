# %% [markdown]
# # Sprint 4 — Deep Learning : Architectures avancées
#
# **AquaSense AI · EHTP MIG S4**
#
# Objectifs :
# - Residual MLP (skip connections)
# - 1D-CNN sur features tabulaires
# - Tableau comparatif MLP vs Residual vs CNN
#
# > Alternative headless : `python -m src.train_dl` ou `python -m src.train_dl tune`

# %%
import sys
from pathlib import Path

import pandas as pd

PROJECT_ROOT = Path("..").resolve()
sys.path.insert(0, str(PROJECT_ROOT))

from src.train_dl import train_dl_models

results = train_dl_models(tune=False, save=True, epochs=100)
pd.DataFrame(results["comparison"])

# %% [markdown]
# ## Grid search + export TFLite (optionnel — long sur CPU)

# %%
# Décommenter pour lancer le tuning complet (9 combinaisons × 100 epochs)
# results_tuned = train_dl_models(tune=True, save=True, epochs=100)
# pd.DataFrame(results_tuned["comparison"])
